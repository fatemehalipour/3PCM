# %% [markdown]
# # 3-Pronged Classification Method for Taxonomic (3PCM)

# %% [markdown]
# In this project, we aim to classify astrovirus RNA sequences at genus level. Although this framework is designed for this type of virus, it can be used for any other viral classfification and clustering task.
#
# The input is a collection of genomic sequences of astrovirus in `.fastsa` format.  The goal is to classify this collection and compare the output to the gound truth if its available.
#
# Since the input sequences are RNA, the alphabet we are using is [A, C, G, U].
#
# The pipeline of the project:
#
# 1.   Load and pre-process the data (Ulternatively we can use pickle files in which the data has been preprocessed and ready for the next steps.)
# 2.   Prong 1 (Supervised Classification)
# 3.   Prong 2 (Unsupervised Clustering)
# 4.   Prong 3 (Extract host information)
# 5.   Putting it all together

# %%
# dependencies
import pickle
import pandas as pd
from pathlib import Path

# install biopython, import it if available
try:
  import Bio
except:
  # !pip install -q biopython
  import Bio

from Bio import SeqIO
print(f"biopython version: {Bio.__version__}")
# Out:
# biopython version: 1.79

# %% [markdown]
# ## 1 Load and pre-process the data
#
# In order to convert DNA sequences from `.fasta` format to `torch.utils.data.Dataset`, we need to go through the following initial steps:
#
# * Read the data from `.fasta` file and convert it to `pandas.DataFrame`. The columns of the dataframe: accession ID, sequence, sequence length, *label*.
# * Explore the dataset and distribution of different labels.
# * Pre-process the data if necessary.

# %% [markdown]
# ### 1.1 Read the data from `.fasta` file
#
# For this purpose we will use `Biopython` library. `Biopython` is a collection of python modules that provide functions for deadling with bioinformatics data and functions for useful computational operations. It also contains a module for parsing sequence files (`SeqIO`).
#
# `SeqIO.parse(file_path, format)` read in sequence files as `SeqRecord` object that contains following info:
# * id - ID used to identify the sequence - a string
# * seq - Seq object containing sequence

# %%
# Setup path to a data folder
data_path = Path("../data/")
fasta_path = data_path / "fasta_files"

# %%
# Get all the fatsa paths
fasta_path_list = list(fasta_path.glob("*.fasta"))

# Open the fasta file
seq_records = []
print(f"Reading the fasta files...")
for i in range(len(fasta_path_list)):
  seq_records.append(next(SeqIO.parse(fasta_path_list[i], "fasta")))

print(f"{len(seq_records)} sequence reconds has been read.")
# Out:
# Reading the fasta files...
# 992 sequence reconds has been read.

# %% [markdown]
# ### 1.2 Extract the labels from metadata file

# %%
def extract_genus_label(seq_name: str,
                        metadata_df):
  """
  A function that extract the genus level label of a sequence record.
  """
  metadata_df = metadata_df.set_index(["Name"])
  return metadata_df.loc[seq_name, "Genus"]

# %%
def extract_host_as_genus_label(seq_name: str,
                                metadata_df):
  """
  A function that extract a potential genus level label of an unlabeled sequence
  record baed on its host.
  """
  metadata_df = metadata_df.set_index(["Name"])
  if metadata_df.loc[seq_name, "Class"] == "Mammalia":
    return "Mamastrovirus"
  elif metadata_df.loc[seq_name, "Class"] == "Aves":
    return "Avastrovirus"
  else:
    return metadata_df.loc[seq_name, "Class"]

# %% [markdown]
# ### 1.3 Extract information about sequences and save data in a `pickle` file. The forrmat of the datasets is a lost of Tuple(label, sequence, accession_id).

# %%
# Create empty lists for dataset2 and dataset 3
dataset2 = []
dataset3 = []

metadata_genus_df = pd.read_csv(data_path / "metadata_genus.csv")
xl_file = pd.ExcelFile(data_path / "metadata_host.xlsx")
# extract different sheets in xl file
dfs = {sheet_name: xl_file.parse(sheet_name) for sheet_name in xl_file.sheet_names}
metadata_host_df = dfs["1039 documents"]


for seq_record in seq_records:
  label = extract_genus_label(seq_record.id, metadata_genus_df)
  sequence = str(seq_record.seq)
  if label != "Unknown":
    record = (label, sequence, seq_record.id)
    dataset2.append(record)
  else:
    label = extract_host_as_genus_label(seq_record.id, metadata_host_df)
    if label in ["Avastrovirus", "Mamastrovirus"]:
      record = (label, sequence, seq_record.id)
      dataset3.append(record)

# %%
from utilities import get_stats
train_data = dataset2
test_data = dataset3

get_stats(train_data, "Dataset 2");
get_stats(test_data, "Dataset 3");
# Out:
# -----------Statistics about Dataset 2: ------------
# # of samples:  684
# # of classes:  2
# min seq length: 5003
# mean seq length: 6629
# max seq length: 7799
# data distribution:
# Avastrovirus =>      213
# Mamastrovirus =>      471
# -------------------------------------------------
# -----------Statistics about Dataset 3: ------------
# # of samples:  229
# # of classes:  2
# min seq length: 5084
# mean seq length: 6432
# max seq length: 8417
# data distribution:
# Avastrovirus =>       42
# Mamastrovirus =>      187
# -------------------------------------------------

# %%
training_data_file = "dataset2.p"
testing_data_file = "dataset3.p"

# %% [markdown]
# ### 1.4 Saving the datasets in `pickle` files

# %%
with open(data_path / training_data_file, "wb") as f:
    pickle.dump(dataset2, f)
with open(data_path / testing_data_file, "wb") as f:
    pickle.dump(dataset3, f)

# %% [markdown]
# ### 1.5 Reading the data from `pickle` files

# %%
from utilities import get_stats
training_data_file = "dataset2.p"
testing_data_file = "dataset3.p"
train_data = pickle.load(open(data_path / training_data_file, "rb"))
test_data = pickle.load(open(data_path / testing_data_file, "rb"))
get_stats(train_data, "Dataset 2");
get_stats(test_data, "Dataset 3");
# Out:
# -----------Statistics about Dataset 2: ------------
# # of samples:  684
# # of classes:  2
# min seq length: 5003
# mean seq length: 6629
# max seq length: 7799
# data distribution:
# Mamastrovirus =>      471
# Avastrovirus =>      213
# -------------------------------------------------
# -----------Statistics about Dataset 3: ------------
# # of samples:  229
# # of classes:  2
# min seq length: 5084
# mean seq length: 6432
# max seq length: 8417
# data distribution:
# Mamastrovirus =>      187
# Avastrovirus =>       42
# -------------------------------------------------

# %% [markdown]
# ## 2. Prong 1

# %%
import statistics

from prong1 import supervised_classification

# %%
"""
Select one of "10-nearest-neighbors", "nearest-centroid-mean",
"nearest-centroid-median", "logistic-regression", "linear-svm",
"quadratic-svm", "cubic-svm", "sgd", "decision-tree", "random-forest",
"adaboost", "gaussian-naive-bayes", "lda", "qda", "multilayer-perceptron"
"""
SUPERVISED_ALGORITHM = "linear-svm"
K = 6 # change this hyperparameter if needed

# %%
def extract_class_names(training_data_file):
    if training_data_file in ["dataset1.p", "dataset2.p", "dataset2_NR.p", "dataset3.p", "dataset3_NR.p"]:
        class_names = sorted(["Avastrovirus", "Mamastrovirus"])
    elif training_data_file == "potyvirus.p":
        class_names = sorted(["Astrovirus", "Potyvirus"])
    elif training_data_file == "mamastrovirus.p":
        class_names = sorted(["HAstV", "Non-HAstV Mamastroviurs"])
    elif training_data_file == "avastrovirus.p":
        class_names = sorted(["GoAstV", "Non-GoAstV Avastrovirus"])
    return class_names
class_names = extract_class_names(training_data_file)

# %%
 'MK404649': 'Mamastrovirus', 'KX907135': 'Mamastrovirus', 'JN420359': 'Mamastrovirus', 'OM451115': 'Mamastrovirus', 'OM451111': 'Mamastrovirus', 'OM451210': 'Mamastrovirus', 'NC_019028': 'Mamastrovirus', 'KX907128': 'Mamastrovirus', 'OK107515': 'Mamastrovirus', 'NC_023636': 'Mamastrovirus', 'MK521912': 'Mamastrovirus', 'KX907131': 'Mamastrovirus', 'KU318317': 'Mamastrovirus', 'MG693176': 'Mamastrovirus', 'KX266904': 'Mamastrovirus', 'MH933758': 'Mamastrovirus', 'MF175075': 'Mamastrovirus', 'JF755422': 'Mamastrovirus', 'KU318315': 'Mamastrovirus', 'KX907133': 'Mamastrovirus', 'KP663426': 'Mamastrovirus', 'KX266906': 'Mamastrovirus', 'OM480545': 'Mamastrovirus', 'JX857868': 'Mamastrovirus', 'MZ819167': 'Mamastrovirus', 'OM104033': 'Mamastrovirus', 'OM451113': 'Mamastrovirus', 'LC201618': 'Mamastrovirus', 'KC692365': 'Mamastrovirus', 'MT267478': 'Mamastrovirus', 'MZ819172': 'Mamastrovirus', 'MT138000': 'Avastrovirus', 'KY271946': 'Mamastrovirus', 'MK096773': 'Mamastrovirus', 'JN420353': 'Mamastrovirus', 'MT137996': 'Avastrovirus', 'NC_019026': 'Mamastrovirus', 'MZ682112': 'Mamastrovirus', 'MK395166': 'Mamastrovirus', 'AB829252': 'Mamastrovirus', 'MT499772': 'Mamastrovirus', 'MT549856': 'Mamastrovirus', 'OM451106': 'Mamastrovirus', 'KU318319': 'Mamastrovirus', 'OM140654': 'Mamastrovirus', 'MH933756': 'Mamastrovirus', 'NC_032484': 'Mamastrovirus', 'OM480533': 'Mamastrovirus', 'MZ546174': 'Mamastrovirus', 'MH933754': 'Mamastrovirus', 'KX266908': 'Mamastrovirus', 'JX544743': 'Mamastrovirus', 'OM451104': 'Mamastrovirus', 'MZ819169': 'Mamastrovirus', 'OM890931': 'Mamastrovirus', 'MT734809': 'Mamastrovirus', 'MT137994': 'Avastrovirus', 'MZ81 ...
# --------------------------------------------------

# %% [markdown]
# ## 3. Prong 2

# %%
from prong2 import unsupervised_clustering

# %%
UNSUPERVISED_ALGORITHM = "k-means++"
CLUSTER_COUNT = 2
K = 6
RUN_COUNT = 10

# %%
def extract_class_names(training_data_file):
    if training_data_file in ["dataset1.p", "dataset2.p", "dataset2_NR.p", "dataset3.p", "dataset3_NR.p"]:
        class_names = sorted(["Avastrovirus", "Mamastrovirus"])
    elif training_data_file == "potyvirus.p":
        class_names = sorted(["Astrovirus", "Potyvirus"])
    elif training_data_file == "mamastrovirus.p":
        class_names = sorted(["HAstV", "Non-HAstV Mamastroviurs"])
    elif training_data_file == "avastrovirus.p":
        class_names = sorted(["GoAstV", "Non-GoAstV Avastrovirus"])
    return class_names
class_names = extract_class_names(training_data_file)

# %%
prong2_pred = unsupervised_clustering(training_data=train_data,
                                      class_names=class_names,
                                      clusters_count=CLUSTER_COUNT,
                                      testing_data=test_data,
                                      k=K,
                                      algorithm=UNSUPERVISED_ALGORITHM)
# Out:
# Prong 2 starting...
# Clustering algorithm: k-means++
# Accuracy: 83.5808%
ovirus', 'OM451210': 'Mamastrovirus', 'NC_019028': 'Avastrovirus', 'KX907128': 'Mamastrovirus', 'OK107515': 'Mamastrovirus', 'NC_023636': 'Mamastrovirus', 'MK521912': 'Mamastrovirus', 'KX907131': 'Mamastrovirus', 'KU318317': 'Mamastrovirus', 'MG693176': 'Mamastrovirus', 'KX266904': 'Mamastrovirus', 'MH933758': 'Mamastrovirus', 'MF175075': 'Mamastrovirus', 'JF755422': 'Avastrovirus', 'KU318315': 'Mamastrovirus', 'KX907133': 'Mamastrovirus', 'KP663426': 'Mamastrovirus', 'KX266906': 'Mamastrovirus', 'OM480545': 'Mamastrovirus', 'JX857868': 'Avastrovirus', 'MZ819167': 'Mamastrovirus', 'OM104033': 'Mamastrovirus', 'OM451113': 'Mamastrovirus', 'LC201618': 'Mamastrovirus', 'KC692365': 'Mamastrovirus', 'MT267478': 'Mamastrovirus', 'MZ819172': 'Mamastrovirus', 'MT138000': 'Avastrovirus', 'KY271946': 'Mamastrovirus', 'MK096773': 'Mamastrovirus', 'JN420353': 'Mamastrovirus', 'MT137996': 'Mamastrovirus', 'NC_019026': 'Avastrovirus', 'MZ682112': 'Mamastrovirus', 'MK395166': 'Mamastrovirus', 'AB829252': 'Avastrovirus', 'MT499772': 'Mamastrovirus', 'MT549856': 'Mamastrovirus', 'OM451106': 'Mamastrovirus', 'KU318319': 'Mamastrovirus', 'OM140654': 'Mamastrovirus', 'MH933756': 'Mamastrovirus', 'NC_032484': 'Mamastrovirus', 'OM480533': 'Mamastrovirus', 'MZ546174': 'Mamastrovirus', 'MH933754': 'Avastrovirus', 'KX266908': 'Mamastrovirus', 'JX544743': 'Mamastrovirus', 'OM451104': 'Mamastrovirus', 'MZ819169': 'Mamastrovirus', 'OM890931': 'Mamastrovirus', 'MT734809': 'Mamastrovirus', 'MT137994': 'Avastrovirus', 'MZ819170': ...
# --------------------------------------------------

# %% [markdown]
# ## 4. Prong 3

# %%
import pandas as pd

def host_identification(testing_data):
  xl_file = pd.ExcelFile(data_path / "metadata_host.xlsx")
  # extract different sheets in xl file
  dfs = {sheet_name: xl_file.parse(sheet_name) for sheet_name in xl_file.sheet_names}
  metadata_host_df = dfs["1039 documents"]
  df = metadata_host_df.set_index(["Name"])

  dict_y_pred_class = {}
  dict_y_pred_species = {}
  for label, seq, name in testing_data:
    dict_y_pred_class[name] = df.loc[name, "Class"]
    dict_y_pred_species[name] = df.loc[name, "Host"]

  print("Host (class level):")
  print(dict_y_pred_class)
  print("Host (species level):")
  print(dict_y_pred_species)
  print("--------------------------------------------------")
  return dict_y_pred_class, dict_y_pred_species

prong3_pred, blah = host_identification(testing_data=test_data);
# Out:
# Host (class level):
# {'JF713711': 'Mammalia', 'KX907134': 'Mammalia', 'KX266901': 'Mammalia', 'MK404648': 'Mammalia', 'FJ375759': 'Mammalia', 'MG660832': 'Mammalia', 'LC577872': 'Mammalia', 'OM480542': 'Mammalia', 'OM451148': 'Mammalia', 'KJ571486': 'Mammalia', 'JF327666': 'Mammalia', 'OM451114': 'Mammalia', 'MN087316': 'Mammalia', 'MN920672': 'Aves', 'JN420358': 'Mammalia', 'KT224358':
# --------------------------------------------------

# %% [markdown]
# ## 5. Putting it all together

# %%
for name in prong1_pred.keys():
  print(f"Predictions for {name}:\nProng 1: {prong1_pred[name]}\nProng 2: {prong2_pred[name]}\nProng 3: Host {prong3_pred[name]}")
  print("--------------------------------------------------")
# Out:
# Predictions for JF713711:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907134:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX266901:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK404648:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for FJ375759:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MG660832:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC577872:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM480542:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451148:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KJ571486:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JF327666:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451114:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN087316:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN920672:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for JN420358:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KT224358:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451116:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN920670:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MT138009:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for KM254166:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for NC_018702:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM480521:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC201620:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC577870:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KF233994:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138010:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MN920669:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MN503236:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OK107512:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ603072:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JA816489:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK089435:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX266903:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC549662:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ357117:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JX857869:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ819166:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138014:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MK327365:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX266907:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MG693175:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907132:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC201619:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451112:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JX857870:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907129:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT137999:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for NC_035471:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_015935:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451110:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451211:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ779126:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX266905:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MH933759:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907130:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KU318316:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK521913:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OK107514:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ603074:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451109:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138016:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MW863310:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_001943:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138008:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MN920671:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for OM451117:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_027426:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MK089434:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX266902:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MF175073:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ357116:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for ON571622:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OK107513:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JF742759:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC577871:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN920668:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MT138011:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MN503237:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM480543:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN503235:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138013:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MK404649:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907135:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JN420359:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451115:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451111:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451210:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_019028:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907128:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OK107515:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_023636:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK521912:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907131:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KU318317:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MG693176:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX266904:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MH933758:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MF175075:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JF755422:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KU318315:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907133:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KP663426:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for KX266906:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM480545:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JX857868:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ819167:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM104033:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451113:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC201618:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KC692365:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT267478:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ819172:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138000:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for KY271946:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK096773:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for JN420353:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT137996:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for NC_019026:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ682112:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK395166:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for AB829252:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT499772:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT549856:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451106:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KU318319:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM140654:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MH933756:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_032484:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM480533:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ546174:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MH933754:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX266908:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JX544743:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451104:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ819169:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM890931:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT734809:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT137994:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MZ819170:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC201616:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JN420351:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138002:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MT138006:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for JN420355:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK096775:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MK404645:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN832787:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN780842:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN920666:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for KU318320:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN920664:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MH933752:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK404647:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN837532:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ218053:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JN420357:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138004:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MW897146:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_032423:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT137992:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for OM451105:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ819168:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT499771:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KM035759:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN920663:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MW082586:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for HUANSSPS:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_035758:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MH933755:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for ON304005:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MZ218054:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KY271945:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138003:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MG921619:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ819171:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC201617:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX022687:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK395165:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JX556693:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT137995:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for NC_032426:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KX907127:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_024498:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT137997:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for NC_019027:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138001:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MK450332:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for JN420352:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for LC201615:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for ON482290:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KP242038:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MH933757:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KU318318:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT549857:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM451107:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JA816485:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN837533:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT470220:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MZ005893:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for OM480534:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT642595:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MH933753:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK404646:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for AF141381:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JX544744:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN920665:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for KX273058:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MW249010:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for KU318321:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK387176:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT152345:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT137993:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for KC609001:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MW897147:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_037655:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK096776:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for BR001717:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for JN420356:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT138005:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MT138007:
# Prong 1: Avastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for JN420354:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MK096774:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MT137991:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MN920667:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Aves
# --------------------------------------------------
# Predictions for MN503238:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for NC_016155:
# Prong 1: Mamastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MG661261:
# Prong 1: Avastrovirus
# Prong 2: Avastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MN837531:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
# Predictions for MT766313:
# Prong 1: Mamastrovirus
# Prong 2: Mamastrovirus
# Prong 3: Host Mammalia
# --------------------------------------------------
